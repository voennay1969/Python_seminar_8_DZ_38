# %% [markdown]
# <a href="https://colab.research.google.com/github/voennay1969/Python_seminar_8_DZ_38/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Новый раздел

# %%
import pandas as pd
import random
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head
# Out:
# <bound method NDFrame.head of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
import pandas as pd
import random
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head
# Out:
# <bound method NDFrame.head of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# # Новый раздел

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import random
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head
# Out:
# <bound method NDFrame.head of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# **Задача 44: В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?**

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  human
# 2  robot
# 3  human
# 4  human

# %%
data = pd.DataFrame({'whoAmi':lst})
data.loc[data['whoAmi']  == 'robot','robot_group'] = '1'
data.loc[data['whoAmi']  != 'robot','robot_group'] = '0'
data.loc[data['whoAmi']  == 'human','human_group'] = '1'
data.loc[data['whoAmi']  != 'robot','human_group'] = '0'

data.head(20)
# Out:
#    whoAmi robot_group human_group
# 0   robot           1         NaN
# 1   human           0           0
# 2   robot           1         NaN
# 3   human           0           0
# 4   human           0           0
# 5   human           0           0
# 6   human           0           0
# 7   robot           1         NaN
# 8   human           0           0
# 9   robot           1         NaN
# 10  robot           1         NaN
# 11  robot           1         NaN
# 12  robot           1         NaN
# 13  human           0           0
# 14  human           0           0
# 15  human           0           0
# 16  robot           1         NaN
# 17  human           0           0
# 18  robot           1         NaN
# 19  robot           1         NaN

# %%
data.loc[data['whoAmI'] == 'human', 'human'] = '1'


data.loc[data['whoAmI'] != 'human', 'human'] = '0'


data.drop(columns='whoAmI')
# Out:
#    human
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
# 5      1
# 6      1
# 7      0
# 8      1
# 9      1
# 10     1
# 11     0
# 12     0
# 13     0
# 14     0
# 15     0
# 16     1
# 17     1
# 18     1
# 19     0

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head(n=10)                                            # - вывод первых 10 строк
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.tail(n=2)       # -вывод последних 2-х строк
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
from pandas.core.dtypes.missing import isnull
df.isnull().sum()                             #- определение в таблице не заполненых данных
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
from pandas.core.dtypes.missing import isnull
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.tail()            # -Вывод песледних 5 строк
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.dtypes               # - определение типа дааных ( в данном случае - ДРОБНЫЕ)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns                            # - вывод названий колонок
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
#           ВЫборка данных

# %%
 import pandas as pd
 df[['latitude','population']]      #- вывод нескольких(2-х) колонок
# Out:
#        latitude  population
# 0         34.19      1015.0
# 1         34.40      1129.0
# 2         33.69       333.0
# 3         33.64       515.0
# 4         33.57       624.0
# ...         ...         ...
# 16995     40.58       907.0
# 16996     40.69      1194.0
# 16997     41.84      1244.0
# 16998     41.80      1298.0
# 16999     40.54       806.0
#
# [17000 rows x 2 columns]

# %% [markdown]
#    Задание: Необходимо вывести столбец total_rooms, у которого медианный возраст
# здания(housing_median_age) меньше 20.

# %%
df[df['housing_median_age'] < 20]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head(n=10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.tail(n=2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df[(df['population'] < 500) & (df['population'] > 0)]['median_house_value'].mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e98de4b1970a> in <cell line: 1>()
# ----> 1 df[(df['population'] < 500) & (df['population'] > 0)]['median_house_value'].mean
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
  df[['latitude','population']]
# Out:
#        latitude  population
# 0         34.19      1015.0
# 1         34.40      1129.0
# 2         33.69       333.0
# 3         33.64       515.0
# 4         33.57       624.0
# ...         ...         ...
# 16995     40.58       907.0
# 16996     40.69      1194.0
# 16997     41.84      1244.0
# 16998     41.80      1298.0
# 16999     40.54       806.0
#
# [17000 rows x 2 columns]

# %%
df[df['housing_median_age'] < 20]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %%
df[df['housing_median_age'] < 20]['total_rooms']
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 10       3741.0
#           ...
# 16983    3140.0
# 16987    3461.0
# 16991    3159.0
# 16997    2677.0
# 16998    2672.0
# Name: total_rooms, Length: 4826, dtype: float64

# %%
df[(df['housing_median_age'] < 20) & (df['housing_median_age'] > 10)]['total_rooms']
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 10       3741.0
#           ...
# 16983    3140.0
# 16987    3461.0
# 16991    3159.0
# 16997    2677.0
# 16998    2672.0
# Name: total_rooms, Length: 3513, dtype: float64

# %%
df[(df['housing_median_age'] < 20) & (df['housing_median_age'] > 10)][['total_rooms','housing_median_age']]
# Out:
#        total_rooms  housing_median_age
# 0           5612.0                15.0
# 1           7650.0                19.0
# 2            720.0                17.0
# 3           1501.0                14.0
# 10          3741.0                16.0
# ...            ...                 ...
# 16983       3140.0                15.0
# 16987       3461.0                17.0
# 16991       3159.0                11.0
# 16997       2677.0                17.0
# 16998       2672.0                19.0
#
# [3513 rows x 2 columns]

# %% [markdown]
# **Текст, выделенный полужирным шрифтом**ПРОСТАЯ СТАТИСТИКА**

# %%
print(df['population'].max())
# Out:
# 35682.0

# %%
print(df['population'].min())
# Out:
# 3.0

# %%
print(df['population'].median())
# Out:
# 1167.0

# %%
print(df['population'].sum())
# Out:
# 24302757.0

# %%
df[['population','total_rooms']].median()
# Out:
# population     1167.0
# total_rooms    2127.0
# dtype: float64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# **Перцентиль - это показатель, используемый в статистике,
# показывающий значение, ниже которого падает определенный процент
# наблюдений в группе наблюдений
# Получить общую картину можно простой командой describe.
#
# count - Общее кол-во не пустых строк.
# mean - среднее значение в столбце.
# std - стандартное отклонение от среднего значения/
# min - минимальное значение.
# max - максимальное значение.
# Числа 25%, 50%, 75% - перцентили.**

# %% [markdown]
# **Изображаем статистические отношения
# Scatterplot (Точечный график)
# Математическая диаграмма, изображающая значения двух переменных в виде
# точек на декартовой плоскости. Библиотека seaborn без труда принимает pandas
# DataFrame(таблицу). Чтобы изобразить отношения между двумя столбцами
# достаточно указать, какой столбец отобразить по оси x, а какой по оси y.
# Для того чтобы начать работу с библиотекой seaborn, ее необходимо импортировать
# к себе в программу:**

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df,x="longitude",y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data=df, x="households", y="population", hue="total_rooms")
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.scatterplot(data=df, x="households", y="population", hue="total_rooms",size=10)
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
cols = ['population', 'median_income', 'housing_median_age','median_house_value']
g = sns.PairGrid(df[cols])
g.map(sns.scatterplot)

# %% [markdown]
# **Линейные графики
# Хорошо подойдут, если есть временная или какая-либо иная последовательность и
# значения, которые могут меняться в зависимости от нее. Для генерации линейных
# графиков в seaborn используется relplot функцию. Она также принимает
# DataFrame, x, y - столбцы.
# Для визуализации выбирается тип line:**

# %%
sns.relplot(x="latitude", y="median_house_value", kind="line", data=df)

# %% [markdown]
# **Можно видеть, что в определенных местах долготы цена за дома резко
# подскакивает. Попробуем визуализировать longitude по отношения к median_house_value и поймем в чем же дело, почему цена так резко подскакивает.**

# %%
sns.relplot(x = 'longitude', y = 'median_house_value', kind = 'line', data = df)

# %% [markdown]
# **Можно видеть, что в определенных местах широты цена за дома также очень
# высока.Используя точечный график можно визуализировать эти отношения с большей
# четкостью. Скорее всего резкий рост цен связан с близостью к ценному объекту,
# повышающему качество жизни, скорее всего побережью океана или реки.**

# %%
sns.scatterplot(data=df, x="latitude", y="longitude", hue="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# **Гистограмма**
#
# **Способ представления табличных данных в графическом виде — в виде столбчатой
# диаграммы. По оси x обычно указывают значение, а по оси y - встречаемость(кол-во
# таких значений в выборке**

# %%
sns.histplot(data=df, x="median_income")
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %% [markdown]
# ** Изобразим гистограмму по housing_median_age.**

# %%
sns.histplot(data = df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# **Давайте посмотрим медианный доход у пожилых жителей.**

# %%
sns.histplot(data=df[df['housing_median_age']>50], x="median_income")
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %% [markdown]
# **Давайте разобьем возрастные группы на 3 категории те кто моложе 20 лет, от 20 до 50 и от 50, чтобы посмотреть влияет ли это на доход.**

# %%
df.loc[df['housing_median_age'] <= 20, 'housing_median_age']
# Out:
# 0        15.0
# 1        19.0
# 2        17.0
# 3        14.0
# 4        20.0
#          ...
# 16987    17.0
# 16988    20.0
# 16991    11.0
# 16997    17.0
# 16998    19.0
# Name: housing_median_age, Length: 5209, dtype: float64

# %%
df[(df['population'] < 500) & (df['population'] > 0)]['median_house_value'].mean

import pandas as pd
df = pd.read_csv(‘california_housing_train.csv’, sep=’,’)
max_households_in_min_population = df[df.population == df[‘population’].min()][‘households’].max()

# %% [markdown]
# **Задача 40: Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population)** ***

# %%
import pandas as pd
df = pd.read_csv(‘california_housing_train.csv’, sep=’,’)
max_households_in_min_population = df[df.population == df[‘population’].min()][‘households’].max()
# Out:
#   File "<ipython-input-9-ce0ae7965bbb>", line 2
#     df = pd.read_csv(‘california_housing_train.csv’, sep=’,’)
#                      ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
import pandas as pd
min_population = df['population'].min()
df.loc[(df['population'] == min_population),['households']].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8a8b422f81ff> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 min_population = df['population'].min()
#       3 df.loc[(df['population'] == min_population),['households']].max()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read.csv('california_housing_train.csv')
df[df('population') < 500]['median_house_value'].mean()
avg = df[df('population') < 500]['median_house_value'].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-a89bd34a94b1> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read.csv('california_housing_train.csv')
#       3 df[df('population') < 500]['median_house_value'].mean()
#       4 avg = df[df('population') < 500]['median_house_value'].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
import pandas as pd
df = pd.read.csv('california_housing_train.csv')
df[df('population') < 500]['median_house_value'].mean()
avg = df[df('population') < 500]['median_house_value'].mean()

# %%
from pandas.io.parsers.readers import read_csv
import pandas as pd
df = pd.read_csv('california_housing_train.csv')
max_households_in_min_population = df[df('population') == df('population').mean()]
['households'].max()
